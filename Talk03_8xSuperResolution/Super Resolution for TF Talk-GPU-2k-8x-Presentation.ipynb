# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

import numpy as np

from PIL import Image
import os
import sys
import bcolz
import matplotlib.pyplot as plt

import tensorflow as tf
import keras

from keras_tqdm import TQDMNotebookCallback
from keras import initializations
from keras.applications.resnet50 import ResNet50, decode_predictions, conv_block, identity_block
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image

from keras.layers import *
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import decode_predictions, preprocess_input

from keras.models import Model
from keras.layers import Input
from keras.layers.convolutional import Convolution2D, AveragePooling2D, MaxPooling2D
from keras.utils.data_utils import get_file
from keras.utils.layer_utils import convert_all_kernels_in_model
import keras.backend as K

from vgg16_avg import VGG16_Avg
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### SDK Versions

# %%
print('TensorFlow:',tf.__version__)
print('Keras:',keras.__version__)
# Out:
# TensorFlow: 1.0.1
# Keras: 1.2.2

# %% [markdown]
# # Celeb Faces

# %%
def save_array(fname, arr): c=bcolz.carray(arr, rootdir=fname, mode='w'); c.flush()
def load_array(fname): return bcolz.open(fname)[:]

# %%
dpath = '/Users/samwitteveen/Dropbox/ai_learning/Key DL Learning'
#dpath = '/home/paperspace/Dropbox/ai_learning/Key DL Learning'
bcolz_hr = '/celeba-176_2k.bc'
bcolz_lr = '/celeba-44_2k.bc'
bcolz_elr = '/celeba-22_2k.bc'
bcolz_test_lr = '/celeba-44_test.bc'
bcolz_test_hr = '/celeba-176_test.bc'
bcolz_test_elr ='/celeba-22_test.bc'

arr_hr = load_array(dpath+bcolz_hr)
arr_lr = load_array(dpath+bcolz_lr)
arr_elr = load_array(dpath+bcolz_elr)
arr_test_hr = load_array(dpath+bcolz_test_hr)
arr_test_elr = load_array(dpath+bcolz_test_elr)

arr_elr.shape
# Out:
# (2000, 22, 22, 3)

# %%
arr_elr.shape
# Out:
# (2000, 22, 22, 3)

# %% [markdown]
# #### Image Preproc

# %%
# vgg preproc
rn_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)
preproc = lambda x: (x - rn_mean)[:, :, :, ::-1]

# %% [markdown]
# ### Set up Network parts
#
# ConvBlock
# ResBlock

# %%
def conv_block(x, num_filters, filter_size, stride=(2,2), mode='same', act=True):
    x = Convolution2D(num_filters, filter_size, filter_size, subsample=stride, border_mode=mode)(x)
    x = BatchNormalization(mode=2)(x)
    return Activation('relu')(x) if act else x

def res_block(initial_input, num_filters=64):
    x = conv_block(initial_input, num_filters, 3, (1,1))
    x = conv_block(x, num_filters, 3, (1,1), act=False)
    return merge([x, initial_input], mode='sum')

# %% [markdown]
# Deconvolution / Transposed Conv / Fractionally Strident Convs

# %%
# Up Sampling block aka Decon
def up_block(x, num_filters, size):
    x = keras.layers.UpSampling2D()(x)
    x = Convolution2D(num_filters, size, size, border_mode='same')(x)
    x = BatchNormalization(mode=2)(x)
    return Activation('relu')(x)

# %% [markdown]
# ### Set up Deconv network - Upsampling network

# %%
def get_upsampling_model_8x(arr):
    inp=Input(arr.shape[1:])
    x=conv_block(inp, 64, 9, (1,1))
    x=res_block(x)
    x=res_block(x)
    x=res_block(x)
    x=res_block(x)
    x=up_block(x, 64, 3)
    x=up_block(x, 64, 3)
    x=up_block(x, 64, 3)
    x=Convolution2D(3, 9, 9, activation='tanh', border_mode='same')(x)
    outp=Lambda(lambda x: (x+1)*127.5)(x)
    return inp,outp

# %%
up_model = Lambda(get_upsampling_model_4x(arr_elr))

# %%
#up_model.summary()

# %%
# this gets the output 
upsampled_inp,upsampled_output = get_upsampling_model_8x(arr_elr)

# %%
up_model2 = Model(upsampled_inp,upsampled_output)
up_model2.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 22, 22, 3)     0
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D) (None, 22, 22, 64)    15616       input_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_25 (BatchNorm (None, 22, 22, 64)    256         convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# activation_17 (Activation)       (None, 22, 22, 64)    0           batchnormalization_25[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D) (None, 22, 22, 64)    36928       activation_17[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_26 (BatchNorm (None, 22, 22, 64)    256         convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# activation_18 (Activation)       (None, 22, 22, 64)    0           batchnormalization_26[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D) (None, 22, 22, 64)    36928       activation_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_27 (BatchNorm (None, 22, 22, 64)    256         convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                  (None, 22, 22, 64)    0           batchnormalization_27[0][0]
#                                                                    activation_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D) (None, 22, 22, 64)    36928       merge_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_28 (BatchNorm (None, 22, 22, 64)    256         convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 22, 22, 64)    0           batchnormalization_28[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D) (None, 22, 22, 64)    36928       activation_19[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_29 (BatchNorm (None, 22, 22, 64)    256         convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                 (None, 22, 22, 64)    0           batchnormalization_29[0][0]
#                                                                    merge_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D) (None, 22, 22, 64)    36928       merge_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_30 (BatchNorm (None, 22, 22, 64)    256         convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 22, 22, 64)    0           batchnormalization_30[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D) (None, 22, 22, 64)    36928       activation_20[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_31 (BatchNorm (None, 22, 22, 64)    256         convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                 (None, 22, 22, 64)    0           batchnormalization_31[0][0]
#                                                                    merge_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D) (None, 22, 22, 64)    36928       merge_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_32 (BatchNorm (None, 22, 22, 64)    256         convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 22, 22, 64)    0           batchnormalization_32[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D) (None, 22, 22, 64)    36928       activation_21[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_33 (BatchNorm (None, 22, 22, 64)    256         convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                 (None, 22, 22, 64)    0           batchnormalization_33[0][0]
#                                                                    merge_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_7 (UpSampling2D)    (None, 44, 44, 64)    0           merge_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D) (None, 44, 44, 64)    36928       upsampling2d_7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_34 (BatchNorm (None, 44, 44, 64)    256         convolution2d_36[0][0]
# ____________________________________________________________________________________________________
# activation_22 (Activation)       (None, 44, 44, 64)    0           batchnormalization_34[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_8 (UpSampling2D)    (None, 88, 88, 64)    0           activation_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_37 (Convolution2D) (None, 88, 88, 64)    36928       upsampling2d_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_35 (BatchNorm (None, 88, 88, 64)    256         convolution2d_37[0][0]
# ____________________________________________________________________________________________________
# activation_23 (Activation)       (None, 88, 88, 64)    0           batchnormalization_35[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_9 (UpSampling2D)    (None, 176, 176, 64)  0           activation_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_38 (Convolution2D) (None, 176, 176, 64)  36928       upsampling2d_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_36 (BatchNorm (None, 176, 176, 64)  256         convolution2d_38[0][0]
# ____________________________________________________________________________________________________
# activation_24 (Activation)       (None, 176, 176, 64)  0           batchnormalization_36[0][0]
# ____________________________________________________________________________________________________
# convolution2d_39 (Convolution2D) (None, 176, 176, 3)   15555       activation_24[0][0]
# ____________________________________________________________________________________________________
# lambda_4 (Lambda)                (None, 176, 176, 3)   0           convolution2d_39[0][0]
# ====================================================================================================
# Total params: 440,451
# Trainable params: 438,915
# Non-trainable params: 1,536
# ____________________________________________________________________________________________________

# %% [markdown]
# ### VGG network
#
# this is only used to for calculating our loss

# %%
#vgg input
vgg_inp=Input(arr_hr.shape[1:])

#vgg network
vgg= VGG16(include_top=False, input_tensor=vgg_inp)
for l in vgg.layers: l.trainable=False

# %%
# Lambda makes a layer of a function/ this makes the preprocessing a layer
preproc_layer = Lambda(preproc)

# %%
# get the vgg output 
vgg_out_layer = vgg.get_layer('block2_conv2').output

# making model Model(inputs, outputs)
vgg_content = Model(vgg_inp, vgg_out_layer)

vgg_content.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, 176, 176, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, 176, 176, 64)  1792        input_4[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, 176, 176, 64)  36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, 88, 88, 64)    0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Convolution2D)     (None, 88, 88, 128)   73856       block1_pool[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Convolution2D)     (None, 88, 88, 128)   147584      block2_conv1[0][0]
# ====================================================================================================
# Total params: 260,160
# Trainable params: 0
# Non-trainable params: 260,160
# ____________________________________________________________________________________________________

# %%
# this is the VGG model with the HR input
vgg_hr_image = vgg_content(preproc_layer(vgg_inp))

# this is the upsampled network
vgg_it_op = vgg_content(preproc_layer(upsampled_output))

# %% [markdown]
# ### Loss and Optimisers

# %%
loss = Lambda(lambda x: K.sqrt(K.mean((x[0]-x[1])**2, (1,2))))([vgg_hr_image, vgg_it_op])

# %%
sr_model = Model([upsampled_inp, vgg_inp], loss)
sr_model.compile('adam', 'mse')

# %% [markdown]
# ### Training

# %%
targ = np.zeros((arr_hr.shape[0], 128))
sr_model.fit([arr_elr, arr_hr], targ, 8, 1)
# Out:
# Epoch 1/1
# 2000/2000 [==============================] - 70s - loss: 58952.6415

# %% [markdown]
# ### Saver

# %%
it_model = Model(upsampled_inp, upsampled_output)
it_model.save_weights('./weights/'+'celba_2k_8x.h5')

# %%
it_model = Model(upsampled_inp, upsampled_output)
it_model.load_weights('./weights/'+'celba_2k_8x.h5')

# %% [markdown]
# ### Examples
#
# show 1. low res 2. hi-res 3. ground truth

# %%
# %time p = it_model.predict(arr_elr[0:50])
p.shape
# Out:
# CPU times: user 57.2 s, sys: 11.5 s, total: 1min 8s
# Wall time: 14.5 s
# (50, 176, 176, 3)

# %%
def compare_pics(x,y):
    fig = plt.figure(figsize=(30,30))
    a=fig.add_subplot(1,2,1)
    imgplot = plt.imshow(x)
    a=fig.add_subplot(1,2,2)
    imgplot = plt.imshow(y)

# %%
compare_pics(arr_elr[10].astype('uint8'), p[10].astype('uint8'))

# %%
compare_pics(arr_elr[13].astype('uint8'), p[13].astype('uint8'))

# %%
compare_pics(arr_hr[13].astype('uint8'),p[13].astype('uint8'))

# %% [markdown]
# # Predicting on Test set that the model hasn't seen

# %%
# %time p = it_model.predict(arr_test_elr[0:50])
p.shape
# Out:
# CPU times: user 56.7 s, sys: 11.3 s, total: 1min 8s
# Wall time: 13.3 s
# (50, 176, 176, 3)

# %%
compare_pics(arr_test_elr[24].astype('uint8'),p[24].astype('uint8'))

# %%
compare_pics(arr_test_hr[24].astype('uint8'),p[24].astype('uint8'))

# %% [markdown]
# # Let's Predict on the Prediction or 64x SR

# %%
new_upsampled_inp,new_upsampled_output = get_upsampling_model_4x(p[20:25])

# %%
new_up_model = Model(new_upsampled_inp,new_upsampled_output)
new_up_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_5 (InputLayer)             (None, 176, 176, 3)   0
# ____________________________________________________________________________________________________
# convolution2d_40 (Convolution2D) (None, 176, 176, 64)  15616       input_5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_37 (BatchNorm (None, 176, 176, 64)  256         convolution2d_40[0][0]
# ____________________________________________________________________________________________________
# activation_25 (Activation)       (None, 176, 176, 64)  0           batchnormalization_37[0][0]
# ____________________________________________________________________________________________________
# convolution2d_41 (Convolution2D) (None, 176, 176, 64)  36928       activation_25[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_38 (BatchNorm (None, 176, 176, 64)  256         convolution2d_41[0][0]
# ____________________________________________________________________________________________________
# activation_26 (Activation)       (None, 176, 176, 64)  0           batchnormalization_38[0][0]
# ____________________________________________________________________________________________________
# convolution2d_42 (Convolution2D) (None, 176, 176, 64)  36928       activation_26[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_39 (BatchNorm (None, 176, 176, 64)  256         convolution2d_42[0][0]
# ____________________________________________________________________________________________________
# merge_13 (Merge)                 (None, 176, 176, 64)  0           batchnormalization_39[0][0]
#                                                                    activation_25[0][0]
# ____________________________________________________________________________________________________
# convolution2d_43 (Convolution2D) (None, 176, 176, 64)  36928       merge_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_40 (BatchNorm (None, 176, 176, 64)  256         convolution2d_43[0][0]
# ____________________________________________________________________________________________________
# activation_27 (Activation)       (None, 176, 176, 64)  0           batchnormalization_40[0][0]
# ____________________________________________________________________________________________________
# convolution2d_44 (Convolution2D) (None, 176, 176, 64)  36928       activation_27[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_41 (BatchNorm (None, 176, 176, 64)  256         convolution2d_44[0][0]
# ____________________________________________________________________________________________________
# merge_14 (Merge)                 (None, 176, 176, 64)  0           batchnormalization_41[0][0]
#                                                                    merge_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_45 (Convolution2D) (None, 176, 176, 64)  36928       merge_14[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_42 (BatchNorm (None, 176, 176, 64)  256         convolution2d_45[0][0]
# ____________________________________________________________________________________________________
# activation_28 (Activation)       (None, 176, 176, 64)  0           batchnormalization_42[0][0]
# ____________________________________________________________________________________________________
# convolution2d_46 (Convolution2D) (None, 176, 176, 64)  36928       activation_28[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_43 (BatchNorm (None, 176, 176, 64)  256         convolution2d_46[0][0]
# ____________________________________________________________________________________________________
# merge_15 (Merge)                 (None, 176, 176, 64)  0           batchnormalization_43[0][0]
#                                                                    merge_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_47 (Convolution2D) (None, 176, 176, 64)  36928       merge_15[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_44 (BatchNorm (None, 176, 176, 64)  256         convolution2d_47[0][0]
# ____________________________________________________________________________________________________
# activation_29 (Activation)       (None, 176, 176, 64)  0           batchnormalization_44[0][0]
# ____________________________________________________________________________________________________
# convolution2d_48 (Convolution2D) (None, 176, 176, 64)  36928       activation_29[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_45 (BatchNorm (None, 176, 176, 64)  256         convolution2d_48[0][0]
# ____________________________________________________________________________________________________
# merge_16 (Merge)                 (None, 176, 176, 64)  0           batchnormalization_45[0][0]
#                                                                    merge_15[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_10 (UpSampling2D)   (None, 352, 352, 64)  0           merge_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_49 (Convolution2D) (None, 352, 352, 64)  36928       upsampling2d_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_46 (BatchNorm (None, 352, 352, 64)  256         convolution2d_49[0][0]
# ____________________________________________________________________________________________________
# activation_30 (Activation)       (None, 352, 352, 64)  0           batchnormalization_46[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_11 (UpSampling2D)   (None, 704, 704, 64)  0           activation_30[0][0]
# ____________________________________________________________________________________________________
# convolution2d_50 (Convolution2D) (None, 704, 704, 64)  36928       upsampling2d_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_47 (BatchNorm (None, 704, 704, 64)  256         convolution2d_50[0][0]
# ____________________________________________________________________________________________________
# activation_31 (Activation)       (None, 704, 704, 64)  0           batchnormalization_47[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_12 (UpSampling2D)   (None, 1408, 1408, 64 0           activation_31[0][0]
# ____________________________________________________________________________________________________
# convolution2d_51 (Convolution2D) (None, 1408, 1408, 64 36928       upsampling2d_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_48 (BatchNorm (None, 1408, 1408, 64 256         convolution2d_51[0][0]
# ____________________________________________________________________________________________________
# activation_32 (Activation)       (None, 1408, 1408, 64 0           batchnormalization_48[0][0]
# ____________________________________________________________________________________________________
# convolution2d_52 (Convolution2D) (None, 1408, 1408, 3) 15555       activation_32[0][0]
# ____________________________________________________________________________________________________
# lambda_7 (Lambda)                (None, 1408, 1408, 3) 0           convolution2d_52[0][0]
# ====================================================================================================
# Total params: 440,451
# Trainable params: 438,915
# Non-trainable params: 1,536
# ____________________________________________________________________________________________________

# %%
new_new_up_model = Model(new_upsampled_inp, new_upsampled_output)
new_new_up_model.load_weights('./weights/'+'celba_2k_8x.h5')

# %%
# %time new_p = new_new_up_model.predict(p[24:25])
# Out:
# CPU times: user 1min 17s, sys: 23.3 s, total: 1min 40s
# Wall time: 23.2 s

# %%
new_p.shape
# Out:
# (1, 1408, 1408, 3)

# %%
compare_pics(new_p[0].astype('uint8'),p[24].astype('uint8'))

# %%
compare_pics(new_p[4].astype('uint8'),arr_test_hr[24].astype('uint8'))

# %% [markdown]
# ### Credits
#
# Papers: "Perceptual Losses for Real-Time Style Transfer and Super-Resolution" by Johnson, et.al
# http://arxiv.org/abs/1603.08155
#
# "A Neural Algorithm of Artistic Style" by Gatys et.al
# http://arxiv.org/abs/1508.06576v2
#
# Code ideas inspired by Jermey Howard's SFData Institute Advanced Deep Learning Course
